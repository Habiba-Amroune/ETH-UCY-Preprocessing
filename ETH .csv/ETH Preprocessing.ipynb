# %%
'''
######################################
Code of the ETH dataset preprocessing
Data preprocessing steps:
                        1) Adjusting the File data to the desired format [#FrameID, PedID, PosX, PosY] 
                        2) Interpolation
                        3) Taking a frame each 10 frames (rather than each 6 frames)
 by Habiba AMROUNE, June 2021
######################################
'''

# %%
import math 
import numpy as np
from numpy import savetxt
from scipy import interpolate
from operator import itemgetter

# %%
'''
Reading the annotations from the obsmat.txt file given by the Biwi dataset, 
obsmat format: [frame_number pedestrian_ID pos_x pos_z pos_y v_x v_z v_y ]
and extracting only [frame_number pedestrian_ID pos_x pos_y] 
'''
data_to_interpolate = np.genfromtxt('eth_hotel.txt',usecols = (0, 1, 2, 4))

#displaying floats with 2 decimal places
float_formatter = "{:.2f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})  

savetxt('Data_formated_eth_hotel.csv', data_to_interpolate, delimiter=',')

# %%
#############################################################################################################
########################################### Interpolation ###################################################
#############################################################################################################
    
interpolated_data = np.empty((0,4), dtype=float)
t=0
for i in range ( 1, int(np.max(data_to_interpolate[:,1])+1)):
    mask = data_to_interpolate[:, 1] == i
    traj_of_ped_i = data_to_interpolate[mask, :]   #list of frames where the pedestrian 'i' appeard 
    if (traj_of_ped_i.size == 0):
        print('-----------------------------------------------------')
        print('this PedID does''t exist in the data :',i)
        x=x+1
        t=t+1
    else:
        x = int(traj_of_ped_i[0,0])                    #the first appearance of the pedestrian 'i'
        y = int(traj_of_ped_i[-1,0])                   #the last appearance of the pedestrian 'i'
        
        if ((x%10) != 0):                              #testing on the first frame
            if ((x%10)<5):
                x = int(traj_of_ped_i[0,0]) - (x%10)
            else:
                x = (int(traj_of_ped_i[0,0]) - (x%10))+10
                
        if ((y%10) != 0):                              #testing on the last frame
            if ((y%10)<5):
                y = int(traj_of_ped_i[-1,0]) - (y%10)
            else:
                y = (int(traj_of_ped_i[-1,0]) - (y%10))+10

        while x < y:                                  #until last appearance of the pedestrian 'i'
            for j in range(0, traj_of_ped_i.shape[0]): 
                z = np.where(traj_of_ped_i[:,0]== x)
                if np.squeeze(traj_of_ped_i[z,0]) == x:   # if the frame exist copy the values of the positions
                    exist_frame = traj_of_ped_i[z,:]
                    interpolated_data = np.append(interpolated_data, exist_frame[0,:,:], axis=0)
                    x=x+1
                else:                                # else: interpolate using scipy.interpolate.interp1d
                    f = interpolate.interp1d(traj_of_ped_i[:,0],[traj_of_ped_i[:,2],traj_of_ped_i[:,3]],fill_value="extrapolate",bounds_error=False)
                    inter = f(x)
                    interpolated_data = np.append(interpolated_data, np.array([[int(x), int(i), float(inter[0]), float(inter[1])]]), axis=0)
                    x=x+1
                if x == y+1:
                    break
    
    percentage = i/(int(np.max(data_to_interpolate[:,1])+1))*100
    percentage = "{:.2f}".format(percentage)
    print('interpolation percentage ', percentage,'%')
    print('-----------------------------------------------------')
        
print('Number of missing pedestrians is: ',t)        
print('-----------------------------------------------------')
print('File infos:')
print('\t Number of trajectories = ',np.max(data_to_interpolate[:,1])-t)
print('\t Number of observations = ',np.max(data_to_interpolate[:,0]))
print('-----------------------------------------------------')


interpolated_data = interpolated_data[np.argsort(interpolated_data[:, 0])]
savetxt('interpolated_data_eth_hotel.csv', interpolated_data, delimiter=',')
# Out:
# <ipython-input-11-5fbb05770d8f>:34: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if np.squeeze(traj_of_ped_i[z,0]) == x:   # if the frame exist copy the values of the positions
# interpolation percentage  0.24 %
# -----------------------------------------------------
# interpolation percentage  0.48 %
# -----------------------------------------------------
# interpolation percentage  0.71 %
# -----------------------------------------------------
# interpolation percentage  0.95 %
# -----------------------------------------------------
# interpolation percentage  1.19 %
# -----------------------------------------------------
# interpolation percentage  1.43 %
# -----------------------------------------------------
# interpolation percentage  1.66 %
# -----------------------------------------------------
# interpolation percentage  1.90 %
# -----------------------------------------------------
# interpolation percentage  2.14 %
# -----------------------------------------------------
# interpolation percentage  2.38 %
# -----------------------------------------------------
# interpolation percentage  2.61 %
# -----------------------------------------------------
# interpolation percentage  2.85 %
# -----------------------------------------------------
# interpolation percentage  3.09 %
# -----------------------------------------------------
# interpolation percentage  3.33 %
# -----------------------------------------------------
# interpolation percentage  3.56 %
# -----------------------------------------------------
# interpolation percentage  3.80 %
# -----------------------------------------------------
# interpolation percentage  4.04 %
# -----------------------------------------------------
# interpolation percentage  4.28 %
# -----------------------------------------------------
# interpolation percentage  4.51 %
# -----------------------------------------------------
# interpolation percentage  4.75 %
# -----------------------------------------------------
# interpolation percentage  4.99 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 22
# interpolation percentage  5.23 %
# -----------------------------------------------------
# interpolation percentage  5.46 %
# -----------------------------------------------------
# interpolation percentage  5.70 %
# -----------------------------------------------------
# interpolation percentage  5.94 %
# -----------------------------------------------------
# interpolation percentage  6.18 %
# -----------------------------------------------------
# interpolation percentage  6.41 %
# -----------------------------------------------------
# interpolation percentage  6.65 %
# -----------------------------------------------------
# interpolation percentage  6.89 %
# -----------------------------------------------------
# interpolation percentage  7.13 %
# -----------------------------------------------------
# interpolation percentage  7.36 %
# -----------------------------------------------------
# interpolation percentage  7.60 %
# -----------------------------------------------------
# interpolation percentage  7.84 %
# -----------------------------------------------------
# interpolation percentage  8.08 %
# -----------------------------------------------------
# interpolation percentage  8.31 %
# -----------------------------------------------------
# interpolation percentage  8.55 %
# -----------------------------------------------------
# interpolation percentage  8.79 %
# -----------------------------------------------------
# interpolation percentage  9.03 %
# -----------------------------------------------------
# interpolation percentage  9.26 %
# -----------------------------------------------------
# interpolation percentage  9.50 %
# -----------------------------------------------------
# interpolation percentage  9.74 %
# -----------------------------------------------------
# interpolation percentage  9.98 %
# -----------------------------------------------------
# interpolation percentage  10.21 %
# -----------------------------------------------------
# interpolation percentage  10.45 %
# -----------------------------------------------------
# interpolation percentage  10.69 %
# -----------------------------------------------------
# interpolation percentage  10.93 %
# -----------------------------------------------------
# interpolation percentage  11.16 %
# -----------------------------------------------------
# interpolation percentage  11.40 %
# -----------------------------------------------------
# interpolation percentage  11.64 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 50
# interpolation percentage  11.88 %
# -----------------------------------------------------
# interpolation percentage  12.11 %
# -----------------------------------------------------
# interpolation percentage  12.35 %
# -----------------------------------------------------
# interpolation percentage  12.59 %
# -----------------------------------------------------
# interpolation percentage  12.83 %
# -----------------------------------------------------
# interpolation percentage  13.06 %
# -----------------------------------------------------
# interpolation percentage  13.30 %
# -----------------------------------------------------
# interpolation percentage  13.54 %
# -----------------------------------------------------
# interpolation percentage  13.78 %
# -----------------------------------------------------
# interpolation percentage  14.01 %
# -----------------------------------------------------
# interpolation percentage  14.25 %
# -----------------------------------------------------
# interpolation percentage  14.49 %
# -----------------------------------------------------
# interpolation percentage  14.73 %
# -----------------------------------------------------
# interpolation percentage  14.96 %
# -----------------------------------------------------
# interpolation percentage  15.20 %
# -----------------------------------------------------
# interpolation percentage  15.44 %
# -----------------------------------------------------
# interpolation percentage  15.68 %
# -----------------------------------------------------
# interpolation percentage  15.91 %
# -----------------------------------------------------
# interpolation percentage  16.15 %
# -----------------------------------------------------
# interpolation percentage  16.39 %
# -----------------------------------------------------
# interpolation percentage  16.63 %
# -----------------------------------------------------
# interpolation percentage  16.86 %
# -----------------------------------------------------
# interpolation percentage  17.10 %
# -----------------------------------------------------
# interpolation percentage  17.34 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 74
# interpolation percentage  17.58 %
# -----------------------------------------------------
# interpolation percentage  17.81 %
# -----------------------------------------------------
# interpolation percentage  18.05 %
# -----------------------------------------------------
# interpolation percentage  18.29 %
# -----------------------------------------------------
# interpolation percentage  18.53 %
# -----------------------------------------------------
# interpolation percentage  18.76 %
# -----------------------------------------------------
# interpolation percentage  19.00 %
# -----------------------------------------------------
# interpolation percentage  19.24 %
# -----------------------------------------------------
# interpolation percentage  19.48 %
# -----------------------------------------------------
# interpolation percentage  19.71 %
# -----------------------------------------------------
# interpolation percentage  19.95 %
# -----------------------------------------------------
# interpolation percentage  20.19 %
# -----------------------------------------------------
# interpolation percentage  20.43 %
# -----------------------------------------------------
# interpolation percentage  20.67 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 88
# interpolation percentage  20.90 %
# -----------------------------------------------------
# interpolation percentage  21.14 %
# -----------------------------------------------------
# interpolation percentage  21.38 %
# -----------------------------------------------------
# interpolation percentage  21.62 %
# -----------------------------------------------------
# interpolation percentage  21.85 %
# -----------------------------------------------------
# interpolation percentage  22.09 %
# -----------------------------------------------------
# interpolation percentage  22.33 %
# -----------------------------------------------------
# interpolation percentage  22.57 %
# -----------------------------------------------------
# interpolation percentage  22.80 %
# -----------------------------------------------------
# interpolation percentage  23.04 %
# -----------------------------------------------------
# interpolation percentage  23.28 %
# -----------------------------------------------------
# interpolation percentage  23.52 %
# -----------------------------------------------------
# interpolation percentage  23.75 %
# -----------------------------------------------------
# interpolation percentage  23.99 %
# -----------------------------------------------------
# interpolation percentage  24.23 %
# -----------------------------------------------------
# interpolation percentage  24.47 %
# -----------------------------------------------------
# interpolation percentage  24.70 %
# -----------------------------------------------------
# interpolation percentage  24.94 %
# -----------------------------------------------------
# interpolation percentage  25.18 %
# -----------------------------------------------------
# interpolation percentage  25.42 %
# -----------------------------------------------------
# interpolation percentage  25.65 %
# -----------------------------------------------------
# interpolation percentage  25.89 %
# -----------------------------------------------------
# interpolation percentage  26.13 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 111
# interpolation percentage  26.37 %
# -----------------------------------------------------
# interpolation percentage  26.60 %
# -----------------------------------------------------
# interpolation percentage  26.84 %
# -----------------------------------------------------
# interpolation percentage  27.08 %
# -----------------------------------------------------
# interpolation percentage  27.32 %
# -----------------------------------------------------
# interpolation percentage  27.55 %
# -----------------------------------------------------
# interpolation percentage  27.79 %
# -----------------------------------------------------
# interpolation percentage  28.03 %
# -----------------------------------------------------
# interpolation percentage  28.27 %
# -----------------------------------------------------
# interpolation percentage  28.50 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 121
# interpolation percentage  28.74 %
# -----------------------------------------------------
# interpolation percentage  28.98 %
# -----------------------------------------------------
# interpolation percentage  29.22 %
# -----------------------------------------------------
# interpolation percentage  29.45 %
# -----------------------------------------------------
# interpolation percentage  29.69 %
# -----------------------------------------------------
# interpolation percentage  29.93 %
# -----------------------------------------------------
# interpolation percentage  30.17 %
# -----------------------------------------------------
# interpolation percentage  30.40 %
# -----------------------------------------------------
# interpolation percentage  30.64 %
# -----------------------------------------------------
# interpolation percentage  30.88 %
# -----------------------------------------------------
# interpolation percentage  31.12 %
# -----------------------------------------------------
# interpolation percentage  31.35 %
# -----------------------------------------------------
# interpolation percentage  31.59 %
# -----------------------------------------------------
# interpolation percentage  31.83 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 135
# interpolation percentage  32.07 %
# -----------------------------------------------------
# interpolation percentage  32.30 %
# -----------------------------------------------------
# interpolation percentage  32.54 %
# -----------------------------------------------------
# interpolation percentage  32.78 %
# -----------------------------------------------------
# interpolation percentage  33.02 %
# -----------------------------------------------------
# interpolation percentage  33.25 %
# -----------------------------------------------------
# interpolation percentage  33.49 %
# -----------------------------------------------------
# interpolation percentage  33.73 %
# -----------------------------------------------------
# interpolation percentage  33.97 %
# -----------------------------------------------------
# interpolation percentage  34.20 %
# -----------------------------------------------------
# interpolation percentage  34.44 %
# -----------------------------------------------------
# interpolation percentage  34.68 %
# -----------------------------------------------------
# interpolation percentage  34.92 %
# -----------------------------------------------------
# interpolation percentage  35.15 %
# -----------------------------------------------------
# interpolation percentage  35.39 %
# -----------------------------------------------------
# interpolation percentage  35.63 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 151
# interpolation percentage  35.87 %
# -----------------------------------------------------
# interpolation percentage  36.10 %
# -----------------------------------------------------
# interpolation percentage  36.34 %
# -----------------------------------------------------
# interpolation percentage  36.58 %
# -----------------------------------------------------
# interpolation percentage  36.82 %
# -----------------------------------------------------
# interpolation percentage  37.05 %
# -----------------------------------------------------
# interpolation percentage  37.29 %
# -----------------------------------------------------
# interpolation percentage  37.53 %
# -----------------------------------------------------
# interpolation percentage  37.77 %
# -----------------------------------------------------
# interpolation percentage  38.00 %
# -----------------------------------------------------
# interpolation percentage  38.24 %
# -----------------------------------------------------
# interpolation percentage  38.48 %
# -----------------------------------------------------
# interpolation percentage  38.72 %
# -----------------------------------------------------
# interpolation percentage  38.95 %
# -----------------------------------------------------
# interpolation percentage  39.19 %
# -----------------------------------------------------
# interpolation percentage  39.43 %
# -----------------------------------------------------
# interpolation percentage  39.67 %
# -----------------------------------------------------
# interpolation percentage  39.90 %
# -----------------------------------------------------
# interpolation percentage  40.14 %
# -----------------------------------------------------
# interpolation percentage  40.38 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 171
# interpolation percentage  40.62 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 172
# interpolation percentage  40.86 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 173
# interpolation percentage  41.09 %
# -----------------------------------------------------
# interpolation percentage  41.33 %
# -----------------------------------------------------
# interpolation percentage  41.57 %
# -----------------------------------------------------
# interpolation percentage  41.81 %
# -----------------------------------------------------
# interpolation percentage  42.04 %
# -----------------------------------------------------
# interpolation percentage  42.28 %
# -----------------------------------------------------
# interpolation percentage  42.52 %
# -----------------------------------------------------
# interpolation percentage  42.76 %
# -----------------------------------------------------
# interpolation percentage  42.99 %
# -----------------------------------------------------
# interpolation percentage  43.23 %
# -----------------------------------------------------
# interpolation percentage  43.47 %
# -----------------------------------------------------
# interpolation percentage  43.71 %
# -----------------------------------------------------
# interpolation percentage  43.94 %
# -----------------------------------------------------
# interpolation percentage  44.18 %
# -----------------------------------------------------
# interpolation percentage  44.42 %
# -----------------------------------------------------
# interpolation percentage  44.66 %
# -----------------------------------------------------
# interpolation percentage  44.89 %
# -----------------------------------------------------
# interpolation percentage  45.13 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 191
# interpolation percentage  45.37 %
# -----------------------------------------------------
# interpolation percentage  45.61 %
# -----------------------------------------------------
# interpolation percentage  45.84 %
# -----------------------------------------------------
# interpolation percentage  46.08 %
# -----------------------------------------------------
# interpolation percentage  46.32 %
# -----------------------------------------------------
# interpolation percentage  46.56 %
# -----------------------------------------------------
# interpolation percentage  46.79 %
# -----------------------------------------------------
# interpolation percentage  47.03 %
# -----------------------------------------------------
# interpolation percentage  47.27 %
# -----------------------------------------------------
# interpolation percentage  47.51 %
# -----------------------------------------------------
# interpolation percentage  47.74 %
# -----------------------------------------------------
# interpolation percentage  47.98 %
# -----------------------------------------------------
# interpolation percentage  48.22 %
# -----------------------------------------------------
# interpolation percentage  48.46 %
# -----------------------------------------------------
# interpolation percentage  48.69 %
# -----------------------------------------------------
# interpolation percentage  48.93 %
# -----------------------------------------------------
# interpolation percentage  49.17 %
# -----------------------------------------------------
# interpolation percentage  49.41 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 209
# interpolation percentage  49.64 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 210
# interpolation percentage  49.88 %
# -----------------------------------------------------
# interpolation percentage  50.12 %
# -----------------------------------------------------
# interpolation percentage  50.36 %
# -----------------------------------------------------
# interpolation percentage  50.59 %
# -----------------------------------------------------
# interpolation percentage  50.83 %
# -----------------------------------------------------
# interpolation percentage  51.07 %
# -----------------------------------------------------
# interpolation percentage  51.31 %
# -----------------------------------------------------
# interpolation percentage  51.54 %
# -----------------------------------------------------
# interpolation percentage  51.78 %
# -----------------------------------------------------
# interpolation percentage  52.02 %
# -----------------------------------------------------
# interpolation percentage  52.26 %
# -----------------------------------------------------
# interpolation percentage  52.49 %
# -----------------------------------------------------
# interpolation percentage  52.73 %
# -----------------------------------------------------
# interpolation percentage  52.97 %
# -----------------------------------------------------
# interpolation percentage  53.21 %
# -----------------------------------------------------
# interpolation percentage  53.44 %
# -----------------------------------------------------
# interpolation percentage  53.68 %
# -----------------------------------------------------
# interpolation percentage  53.92 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 228
# interpolation percentage  54.16 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 229
# interpolation percentage  54.39 %
# -----------------------------------------------------
# interpolation percentage  54.63 %
# -----------------------------------------------------
# interpolation percentage  54.87 %
# -----------------------------------------------------
# interpolation percentage  55.11 %
# -----------------------------------------------------
# interpolation percentage  55.34 %
# -----------------------------------------------------
# interpolation percentage  55.58 %
# -----------------------------------------------------
# interpolation percentage  55.82 %
# -----------------------------------------------------
# interpolation percentage  56.06 %
# -----------------------------------------------------
# interpolation percentage  56.29 %
# -----------------------------------------------------
# interpolation percentage  56.53 %
# -----------------------------------------------------
# interpolation percentage  56.77 %
# -----------------------------------------------------
# interpolation percentage  57.01 %
# -----------------------------------------------------
# interpolation percentage  57.24 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 242
# interpolation percentage  57.48 %
# -----------------------------------------------------
# interpolation percentage  57.72 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 244
# interpolation percentage  57.96 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 245
# interpolation percentage  58.19 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 246
# interpolation percentage  58.43 %
# -----------------------------------------------------
# interpolation percentage  58.67 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 248
# interpolation percentage  58.91 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 249
# interpolation percentage  59.14 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 250
# interpolation percentage  59.38 %
# -----------------------------------------------------
# interpolation percentage  59.62 %
# -----------------------------------------------------
# interpolation percentage  59.86 %
# -----------------------------------------------------
# interpolation percentage  60.10 %
# -----------------------------------------------------
# interpolation percentage  60.33 %
# -----------------------------------------------------
# interpolation percentage  60.57 %
# -----------------------------------------------------
# interpolation percentage  60.81 %
# -----------------------------------------------------
# interpolation percentage  61.05 %
# -----------------------------------------------------
# interpolation percentage  61.28 %
# -----------------------------------------------------
# interpolation percentage  61.52 %
# -----------------------------------------------------
# interpolation percentage  61.76 %
# -----------------------------------------------------
# interpolation percentage  62.00 %
# -----------------------------------------------------
# interpolation percentage  62.23 %
# -----------------------------------------------------
# interpolation percentage  62.47 %
# -----------------------------------------------------
# interpolation percentage  62.71 %
# -----------------------------------------------------
# interpolation percentage  62.95 %
# -----------------------------------------------------
# interpolation percentage  63.18 %
# -----------------------------------------------------
# interpolation percentage  63.42 %
# -----------------------------------------------------
# interpolation percentage  63.66 %
# -----------------------------------------------------
# interpolation percentage  63.90 %
# -----------------------------------------------------
# interpolation percentage  64.13 %
# -----------------------------------------------------
# interpolation percentage  64.37 %
# -----------------------------------------------------
# interpolation percentage  64.61 %
# -----------------------------------------------------
# interpolation percentage  64.85 %
# -----------------------------------------------------
# interpolation percentage  65.08 %
# -----------------------------------------------------
# interpolation percentage  65.32 %
# -----------------------------------------------------
# interpolation percentage  65.56 %
# -----------------------------------------------------
# interpolation percentage  65.80 %
# -----------------------------------------------------
# interpolation percentage  66.03 %
# -----------------------------------------------------
# interpolation percentage  66.27 %
# -----------------------------------------------------
# interpolation percentage  66.51 %
# -----------------------------------------------------
# interpolation percentage  66.75 %
# -----------------------------------------------------
# interpolation percentage  66.98 %
# -----------------------------------------------------
# interpolation percentage  67.22 %
# -----------------------------------------------------
# interpolation percentage  67.46 %
# -----------------------------------------------------
# interpolation percentage  67.70 %
# -----------------------------------------------------
# interpolation percentage  67.93 %
# -----------------------------------------------------
# interpolation percentage  68.17 %
# -----------------------------------------------------
# interpolation percentage  68.41 %
# -----------------------------------------------------
# interpolation percentage  68.65 %
# -----------------------------------------------------
# interpolation percentage  68.88 %
# -----------------------------------------------------
# interpolation percentage  69.12 %
# -----------------------------------------------------
# interpolation percentage  69.36 %
# -----------------------------------------------------
# interpolation percentage  69.60 %
# -----------------------------------------------------
# interpolation percentage  69.83 %
# -----------------------------------------------------
# interpolation percentage  70.07 %
# -----------------------------------------------------
# interpolation percentage  70.31 %
# -----------------------------------------------------
# interpolation percentage  70.55 %
# -----------------------------------------------------
# interpolation percentage  70.78 %
# -----------------------------------------------------
# interpolation percentage  71.02 %
# -----------------------------------------------------
# interpolation percentage  71.26 %
# -----------------------------------------------------
# interpolation percentage  71.50 %
# -----------------------------------------------------
# interpolation percentage  71.73 %
# -----------------------------------------------------
# interpolation percentage  71.97 %
# -----------------------------------------------------
# interpolation percentage  72.21 %
# -----------------------------------------------------
# interpolation percentage  72.45 %
# -----------------------------------------------------
# interpolation percentage  72.68 %
# -----------------------------------------------------
# interpolation percentage  72.92 %
# -----------------------------------------------------
# interpolation percentage  73.16 %
# -----------------------------------------------------
# interpolation percentage  73.40 %
# -----------------------------------------------------
# interpolation percentage  73.63 %
# -----------------------------------------------------
# interpolation percentage  73.87 %
# -----------------------------------------------------
# interpolation percentage  74.11 %
# -----------------------------------------------------
# interpolation percentage  74.35 %
# -----------------------------------------------------
# interpolation percentage  74.58 %
# -----------------------------------------------------
# interpolation percentage  74.82 %
# -----------------------------------------------------
# interpolation percentage  75.06 %
# -----------------------------------------------------
# interpolation percentage  75.30 %
# -----------------------------------------------------
# interpolation percentage  75.53 %
# -----------------------------------------------------
# interpolation percentage  75.77 %
# -----------------------------------------------------
# interpolation percentage  76.01 %
# -----------------------------------------------------
# interpolation percentage  76.25 %
# -----------------------------------------------------
# interpolation percentage  76.48 %
# -----------------------------------------------------
# interpolation percentage  76.72 %
# -----------------------------------------------------
# interpolation percentage  76.96 %
# -----------------------------------------------------
# interpolation percentage  77.20 %
# -----------------------------------------------------
# interpolation percentage  77.43 %
# -----------------------------------------------------
# interpolation percentage  77.67 %
# -----------------------------------------------------
# interpolation percentage  77.91 %
# -----------------------------------------------------
# interpolation percentage  78.15 %
# -----------------------------------------------------
# interpolation percentage  78.38 %
# -----------------------------------------------------
# interpolation percentage  78.62 %
# -----------------------------------------------------
# interpolation percentage  78.86 %
# -----------------------------------------------------
# interpolation percentage  79.10 %
# -----------------------------------------------------
# interpolation percentage  79.33 %
# -----------------------------------------------------
# interpolation percentage  79.57 %
# -----------------------------------------------------
# interpolation percentage  79.81 %
# -----------------------------------------------------
# interpolation percentage  80.05 %
# -----------------------------------------------------
# interpolation percentage  80.29 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 339
# interpolation percentage  80.52 %
# -----------------------------------------------------
# interpolation percentage  80.76 %
# -----------------------------------------------------
# interpolation percentage  81.00 %
# -----------------------------------------------------
# interpolation percentage  81.24 %
# -----------------------------------------------------
# interpolation percentage  81.47 %
# -----------------------------------------------------
# interpolation percentage  81.71 %
# -----------------------------------------------------
# interpolation percentage  81.95 %
# -----------------------------------------------------
# interpolation percentage  82.19 %
# -----------------------------------------------------
# interpolation percentage  82.42 %
# -----------------------------------------------------
# interpolation percentage  82.66 %
# -----------------------------------------------------
# interpolation percentage  82.90 %
# -----------------------------------------------------
# interpolation percentage  83.14 %
# -----------------------------------------------------
# interpolation percentage  83.37 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 352
# interpolation percentage  83.61 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 353
# interpolation percentage  83.85 %
# -----------------------------------------------------
# interpolation percentage  84.09 %
# -----------------------------------------------------
# interpolation percentage  84.32 %
# -----------------------------------------------------
# interpolation percentage  84.56 %
# -----------------------------------------------------
# interpolation percentage  84.80 %
# -----------------------------------------------------
# interpolation percentage  85.04 %
# -----------------------------------------------------
# interpolation percentage  85.27 %
# -----------------------------------------------------
# interpolation percentage  85.51 %
# -----------------------------------------------------
# interpolation percentage  85.75 %
# -----------------------------------------------------
# interpolation percentage  85.99 %
# -----------------------------------------------------
# interpolation percentage  86.22 %
# -----------------------------------------------------
# interpolation percentage  86.46 %
# -----------------------------------------------------
# interpolation percentage  86.70 %
# -----------------------------------------------------
# interpolation percentage  86.94 %
# -----------------------------------------------------
# interpolation percentage  87.17 %
# -----------------------------------------------------
# interpolation percentage  87.41 %
# -----------------------------------------------------
# interpolation percentage  87.65 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 370
# interpolation percentage  87.89 %
# -----------------------------------------------------
# interpolation percentage  88.12 %
# -----------------------------------------------------
# interpolation percentage  88.36 %
# -----------------------------------------------------
# interpolation percentage  88.60 %
# -----------------------------------------------------
# interpolation percentage  88.84 %
# -----------------------------------------------------
# interpolation percentage  89.07 %
# -----------------------------------------------------
# interpolation percentage  89.31 %
# -----------------------------------------------------
# interpolation percentage  89.55 %
# -----------------------------------------------------
# interpolation percentage  89.79 %
# -----------------------------------------------------
# interpolation percentage  90.02 %
# -----------------------------------------------------
# interpolation percentage  90.26 %
# -----------------------------------------------------
# interpolation percentage  90.50 %
# -----------------------------------------------------
# interpolation percentage  90.74 %
# -----------------------------------------------------
# interpolation percentage  90.97 %
# -----------------------------------------------------
# interpolation percentage  91.21 %
# -----------------------------------------------------
# interpolation percentage  91.45 %
# -----------------------------------------------------
# interpolation percentage  91.69 %
# -----------------------------------------------------
# interpolation percentage  91.92 %
# -----------------------------------------------------
# interpolation percentage  92.16 %
# -----------------------------------------------------
# interpolation percentage  92.40 %
# -----------------------------------------------------
# interpolation percentage  92.64 %
# -----------------------------------------------------
# interpolation percentage  92.87 %
# -----------------------------------------------------
# interpolation percentage  93.11 %
# -----------------------------------------------------
# interpolation percentage  93.35 %
# -----------------------------------------------------
# interpolation percentage  93.59 %
# -----------------------------------------------------
# interpolation percentage  93.82 %
# -----------------------------------------------------
# interpolation percentage  94.06 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 397
# interpolation percentage  94.30 %
# -----------------------------------------------------
# interpolation percentage  94.54 %
# -----------------------------------------------------
# interpolation percentage  94.77 %
# -----------------------------------------------------
# interpolation percentage  95.01 %
# -----------------------------------------------------
# interpolation percentage  95.25 %
# -----------------------------------------------------
# interpolation percentage  95.49 %
# -----------------------------------------------------
# interpolation percentage  95.72 %
# -----------------------------------------------------
# interpolation percentage  95.96 %
# -----------------------------------------------------
# interpolation percentage  96.20 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 406
# interpolation percentage  96.44 %
# -----------------------------------------------------
# -----------------------------------------------------
# this PedID doest exist in the data 407
# interpolation percentage  96.67 %
# -----------------------------------------------------
# interpolation percentage  96.91 %
# -----------------------------------------------------
# interpolation percentage  97.15 %
# -----------------------------------------------------
# interpolation percentage  97.39 %
# -----------------------------------------------------
# interpolation percentage  97.62 %
# -----------------------------------------------------
# interpolation percentage  97.86 %
# -----------------------------------------------------
# interpolation percentage  98.10 %
# -----------------------------------------------------
# interpolation percentage  98.34 %
# -----------------------------------------------------
# interpolation percentage  98.57 %
# -----------------------------------------------------
# interpolation percentage  98.81 %
# -----------------------------------------------------
# interpolation percentage  99.05 %
# -----------------------------------------------------
# interpolation percentage  99.29 %
# -----------------------------------------------------
# interpolation percentage  99.52 %
# -----------------------------------------------------
# interpolation percentage  99.76 %
# -----------------------------------------------------
# Number of missing pedestrians is:  30
# -----------------------------------------------------
# File infos:
# 	 Number of trajectories =  390.0
# 	 Number of observations =  18061.0
# -----------------------------------------------------

# %%
#############################################################################################################
################################### Taking a frame each 10 frames ###########################################
#############################################################################################################
def frames_10(inter_data):
    frames = inter_data[:,0]
    frames = sorted(frames)
    frames = np.unique(frames)
    final_data = []
    for i in range(0,len(frames)):
        id = frames[i]
        if (((id%10)==0) or(id==0)):
            frm = inter_data[inter_data[:,0] == id,:]
            final_data.extend(frm) 
    final_data = np.unique(final_data, axis=0)
    return final_data

Final_data = frames_10(interpolated_data)
savetxt('Final_data_eth_hotel.csv', Final_data, delimiter=',')
